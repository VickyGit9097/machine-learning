# %%
## dimensionality reduction

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# C:\Users\bikki\AppData\Local\Temp\ipykernel_7568\1285016483.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("Heart.csv")
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
df=df.drop(columns="Unnamed: 0")
df
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0     63    1       typical     145   233    1        2    150      0
# 1     67    1  asymptomatic     160   286    0        2    108      1
# 2     67    1  asymptomatic     120   229    0        2    129      1
# 3     37    1    nonanginal     130   250    0        0    187      0
# 4     41    0    nontypical     130   204    0        2    172      0
# ..   ...  ...           ...     ...   ...  ...      ...    ...    ...
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 0        2.3      3  0.0       fixed   No
# ...

# %%
df["ChestPain"]=df["ChestPain"].astype("category")
df["ChestPain"]=df["ChestPain"].cat.codes

df["Thal"]=df["Thal"].astype("category")
df["Thal"]=df["Thal"].cat.codes

df["AHD"]=df["AHD"].astype("category")
df["AHD"]=df["AHD"].cat.codes

# %%
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
# 302   38    1          1     138   175    0        0    173      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
df.isnull().sum()
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         0
# AHD          0
# dtype: int64

# %%
df=df.dropna()
df
# Out:
#      Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1          3     145   233    1        2    150      0      2.3
# 1     67    1          0     160   286    0        2    108      1      1.5
# 2     67    1          0     120   229    0        2    129      1      2.6
# 3     37    1          1     130   250    0        0    187      0      3.5
# 4     41    0          2     130   204    0        2    172      0      1.4
# ..   ...  ...        ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0          0     140   241    0        0    123      1      0.2
# 298   45    1          3     110   264    0        0    132      0      1.2
# 299   68    1          0     144   193    1        0    141      0      3.4
# 300   57    1          0     130   131    0        0    115      1      1.2
# 301   57    0          2     130   236    0        2    174      0      0.0
#
#      Slope   Ca  Thal  AHD
# 0        3  0.0     0    0
# ...

# %%
x=df.drop(columns="AHD")
y=df["AHD"]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=scaler.fit_transform(x)

# %%
x[:5]
# Out:
# array([[ 0.94067407,  0.69296322,  2.24755822,  0.75419084, -0.27206074,
#          2.40737503,  1.01012964,  0.02159942, -0.69825654,  1.07427684,
#          2.26765706, -0.71830622, -2.1414052 ],
#        [ 1.38482969,  0.69296322, -0.87327726,  1.60279745,  0.75055465,
#         -0.4153902 ,  1.01012964, -1.8111405 ,  1.4321384 ,  0.38572641,
#          0.64557701,  2.48726932, -0.50803746],
#        [ 1.38482969,  0.69296322, -0.87327726, -0.6601535 , -0.34923926,
#         -0.4153902 ,  1.01012964, -0.89477054,  1.4321384 ,  1.33248325,
#          0.64557701,  1.41874414,  1.12533028],
#        [-1.94633746,  0.69296322,  0.16700123, -0.09441576,  0.05594797,
#         -0.4153902 , -1.00339544,  1.63615602, -0.69825654,  2.10710247,
#          2.26765706, -0.71830622, -0.50803746],
#        [-1.50218184, -1.44307804,  1.20727972, -0.09441576, -0.831605  ,
#         -0.4153902 ,  1.01012964,  0.98160604, -0.69825654,  0.29965761,
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)
len(x_train)
# Out:
# 209

# %%
len(x_test)
# Out:
# 90

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
x_pca=pca.fit_transform(x)
x_pca.shape
# Out:
# (299, 3)

# %%
x_pca_train,x_pca_test,y_train,y_test=train_test_split(x_pca,y,test_size=.30,random_state=1)
x_pca_train.shape
# Out:
# (209, 3)

# %%
model.fit(x_pca_train,y_train)
model.score(x_pca_test,y_test)
# Out:
# 0.8111111111111111

# %%
from sklearn.decomposition import PCA
pca=PCA(0.80)
x_pca1=pca.fit_transform(x)
x_pca1.shape
# Out:
# (299, 8)

# %%
x_pca1_train,x_pca1_test,y_train,y_test=train_test_split(x_pca1,y,test_size=.30,random_state=1)
len(x_pca1_train)
# Out:
# 209

# %%
model.fit(x_pca1_train,y_train)
model.score(x_pca1_test,y_test)
# Out:
# 0.7888888888888889
