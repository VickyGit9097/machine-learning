# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\bikki\AppData\Local\Temp\ipykernel_21240\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("insurance (1).csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df["sex"]=df["sex"].astype("category")
df["sex"]=df["sex"].cat.codes

df["smoker"]=df["smoker"].astype("category")
df["smoker"]=df["smoker"].cat.codes

df["region"]=df["region"].astype("category")
df["region"]=df["region"].cat.codes

# %%
df
# Out:
#       age  sex     bmi  children  smoker  region      charges
# 0      19    0  27.900         0       1       3  16884.92400
# 1      18    1  33.770         1       0       2   1725.55230
# 2      28    1  33.000         3       0       2   4449.46200
# 3      33    1  22.705         0       0       1  21984.47061
# 4      32    1  28.880         0       0       1   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    1  30.970         3       0       1  10600.54830
# 1334   18    0  31.920         0       0       0   2205.98080
# 1335   18    0  36.850         0       0       2   1629.83350
# 1336   21    0  25.800         0       0       3   2007.94500
# 1337   61    0  29.070         0       1       1  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x=df.drop(["charges"],axis=1)
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    0  27.900         0       1       3
# 1      18    1  33.770         1       0       2
# 2      28    1  33.000         3       0       2
# 3      33    1  22.705         0       0       1
# 4      32    1  28.880         0       0       1
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    1  30.970         3       0       1
# 1334   18    0  31.920         0       0       0
# 1335   18    0  36.850         0       0       2
# 1336   21    0  25.800         0       0       3
# 1337   61    0  29.070         0       1       1
#
# [1338 rows x 6 columns]

# %%
y=df["charges"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.40,random_state=1)

# %%
x_train
# Out:
#       age  sex     bmi  children  smoker  region
# 5      31    0  25.740         0       0       2
# 1250   24    1  29.830         0       1       0
# 947    37    1  34.200         1       1       0
# 1036   22    1  37.070         2       1       2
# 874    44    1  21.850         3       0       0
# ...   ...  ...     ...       ...     ...     ...
# 715    60    1  28.900         0       0       3
# 905    26    0  29.355         2       0       0
# 1096   51    0  34.960         2       1       0
# 235    40    0  22.220         2       1       2
# 1061   57    1  27.940         1       0       2
#
# [802 rows x 6 columns]

# %%
x_test
# Out:
#       age  sex     bmi  children  smoker  region
# 559    19    1  35.530         0       0       1
# 1087   57    1  31.540         0       0       1
# 1020   51    1  37.000         0       0       3
# 460    49    0  36.630         3       0       2
# 802    21    1  22.300         1       0       3
# ...   ...  ...     ...       ...     ...     ...
# 708    31    0  30.495         3       0       0
# 479    23    1  32.560         0       0       2
# 541    20    0  31.790         2       0       2
# 117    29    0  27.940         1       1       2
# 768    64    0  39.700         0       0       3
#
# [536 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train[:5]
# Out:
# array([[-0.56619132, -1.043332  , -0.81774198, -0.92024327, -0.51088775,
#          0.42314034],
#        [-1.06667912,  0.95846768, -0.13748521, -0.92024327,  1.95737715,
#         -1.3771703 ],
#        [-0.13720177,  0.95846768,  0.58934171, -0.10653312,  1.95737715,
#         -1.3771703 ],
#        [-1.20967564,  0.95846768,  1.0666857 ,  0.70717702,  1.95737715,
#          0.42314034],
#        [ 0.36328604,  0.95846768, -1.46473435,  1.52088717, -0.51088775,
#         -1.3771703 ]])

# %%
y_train[:5]
# Out:
# 5        3756.6216
# 1250    18648.4217
# 947     39047.2850
# 1036    37484.4493
# 874      8891.1395
# Name: charges, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.7582107332092474

# %%
x_test[:5]
# Out:
# array([[-1.42417041,  0.95846768,  0.8105499 , -0.92024327, -0.51088775,
#         -0.47701498],
#        [ 1.29276339,  0.95846768,  0.14692533, -0.92024327, -0.51088775,
#         -0.47701498],
#        [ 0.86377384,  0.95846768,  1.05504316, -0.92024327, -0.51088775,
#          1.32329567],
#        [ 0.72077733, -1.043332  ,  0.99350404,  1.52088717, -0.51088775,
#          0.42314034],
#        [-1.2811739 ,  0.95846768, -1.38988948, -0.10653312, -0.51088775,
#          1.32329567]])

# %%
model.score(x_test,y_test)
# Out:
# 0.7381485193570552

# %% [markdown]
# ## l1-lasso regression

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=50,max_iter=100,tol=0.1)
lasso.fit(x_train,y_train)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso.score(x_train,y_train)
# Out:
# 0.7581053148956785

# %%
lasso.score(x_test,y_test)
# Out:
# 0.7381658956587644

# %% [markdown]
# ## l2-Ridge regression

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=50,max_iter=100,tol=0.1)
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge.score(x_train,y_train)
# Out:
# 0.7556707472912187

# %%
ridge.score(x_test,y_test)
# Out:
# 0.7354470296076547
